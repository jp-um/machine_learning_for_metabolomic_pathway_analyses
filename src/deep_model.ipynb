# %%
import sys

import rdkit # required for cheminformatics functionality (small molecules)
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import DataStructs

import numpy as np
np.set_printoptions(threshold=sys.maxsize)

# %% [markdown]
# Create two lists from the data file, one with the molecules and the other with the classes of the molecules.  The classes are integers [0..10] representing the 11 classes.  Keep in mind that this is a multi-class problem, i.e. each  molecule (metabolite) may have more than one class.

# %%
# load the molecules
with open("../data/kegg_classes.txt") as f:
    mols_str, classes = zip(*[ line.strip().split() for line in f])

# %%
# encode each molecule using deep smiles
import deepsmiles
print("DeepSMILES version: %s" % deepsmiles.__version__)

converter = deepsmiles.Converter(rings=True, branches=True)

# a list of deep smiles per molecule
deep_smiles_enc = [ converter.encode(m) for m in mols_str ]
# Out:
# DeepSMILES version: 1.0.1

# %%
deep_smiles_enc
# Out:
# ['CC=O)C=O)O',
#  'CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'OCCOCO)CO)CO)C6O',
#  'CC=O)O',
#  'O=CO)CC=O)C=O)O',
#  'CcnccC[n+]cscCCOP=O)O)OP=O)O)O)))))))c5C)))))))cN)n6',
#  'C=COP=O)O)O)))C=O)O',
#  'CC=O',
#  'O=PO)O)OCOCCO))CO)CO)C6O',
#  'O=CCO))COP=O)O)O',
#  'O=CCO)COP=O)O)O',
#  'CCO)C=O)O',
#  'O=CO)CO)COP=O)O)O',
#  'OCCOCO)CO)CO)C6O',
#  'O=COP=O)O)O)))CO)COP=O)O)O',
#  'OCCOCO)CO)CO)C6O',
#  'CCO',
#  'O=CO)CCO))OP=O)O)O',
#  'O=PO)O)OCCOCO)CO)CO)C6O',
#  'O=CO)CCOP=O)O)O))))OP=O)O)O',
#  'O=PO)O)OCCOCO)CO)CO)C6O',
#  'OCcccccc6OCOCCO))CO)CO)C6O',
#  'CcnccC[n+]cCC)O))scCCOP=O)O)OP=O)O)O)))))))c5C)))))))cN)n6',
#  'O=PO)O)OCCOCO)CO))CO)C5O',
#  'O=PO)O)OCCOCO)COP=O)O)O))))CO)C5O',
#  'OCCOCOccccO)cc6)))))))CO)CO)C6O',
#  'O=PO)O)OCCOCOccccO)cc6)))))))CO)CO)C6O',
#  'O=PO)O)OCCOCOcccccc6CO)))))))))CO)CO)C6O',
#  '[*]NC=O)CCCCCCCSS5',
#  '[*]NC=O)CCCCCS)CCS',
#  '[*]NC=O)CCCCCS)CCSCC)=O',
#  'CC=O)C=O)O',
#  'CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'O=CO)CCC=O)C=O)O',
#  'O=CO)CC=O)C=O)O',
#  'O=CO)CCC=O)O',
#  'CcnccC[n+]cscCCOP=O)O)OP=O)O)O)))))))c5C)))))))cN)n6',
#  'C=COP=O)O)O)))C=O)O',
#  'CCC)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O)))))))))))))))CO)C=O)NCCC=O)NCCSC=O)CCC=O)O',
#  'O=CO)C=CC=O)O',
#  'O=CO)CCO)C=O)O',
#  'O=CO)CCO)CC=O)O)))C=O)O',
#  'O=CO)CCC=O)O))CO)C=O)O',
#  'O=CO)C=CCC=O)O)))C=O)O',
#  'CcnccC[n+]cCC)O))scCCOP=O)O)OP=O)O)O)))))))c5C)))))))cN)n6',
#  'O=CO)CCC=O)O))C=O)C=O)O',
#  'CcnccC[n+]cCO)CCC=O)O)))))scCCOP=O)O)OP=O)O)O)))))))c5C)))))))cN)n6',
#  '[*]NC=O)CCCCCCCSS5',
#  '[*]NC=O)CCCCCS)CCS',
#  '[*]NC=O)CCCCCS)CCSC=O)CCC=O)O',
#  '[*]NC=O)CCCCCS)CCSCC)=O',
#  'CC=O)C=O)O',
#  'OCCOCO)CO)CO)C6O',
#  'O=PO)O)OCCOCO)CO)C5O',
#  'O=CCO)COP=O)O)O',
#  'O=PO)O)OCCOCOP=O)O)OP=O)O)O)))))CO)C5O',
#  'OCCOCO)CO)C5O',
#  'O=CO)CO)COP=O)O)O',
#  'O=COCCO))CO)CO)C6O',
#  'O=CCO))CO)CO)COP=O)O)O',
#  'O=CO)C=O)CCO)CO)CO',
#  'OCCOCO)CO)CO)C6O',
#  'O=CCO))CO)CO)COP=O)O)O',
#  'O=CO)CO)CO)CO)CO)CO',
#  'O=CO)CO)CO',
#  'O=CCO)CO)COP=O)O)O',
#  'O=CO)CO)CO)CO)CO)COP=O)O)O',
#  'O=CCO)CO',
#  'O=PO)O)OCOCCO))CO)C5O',
#  'O=CO)CCO))OP=O)O)O',
#  'O=PO)O)OCCOCO)CO)CO)C6O',
#  'O=PO)O)OCCCO)CCO))O5',
#  'O=PO)O)OCCOCO)CC5O',
#  'O=PO)O)OCCOCOP=O)O)O)))CO)C5O',
#  'O=PO)O)OCCOCO)CO)CO)C6O',
#  'O=CO)C=O)CO)CO)CO)COP=O)O)O',
#  'O=COCCOP=O)O)O))))CO)CO)C6O',
#  'OCCOCO)CC5O',
#  'NCC=O)O))CO)CO)CO)CO',
#  'O=CO)C=O)CCO)CO)COP=O)O)O',
#  'O=PO)O)OCCOCO)CO))CO)C5O',
#  'O=PO)O)OCCOCO)COP=O)O)O))))CO)C5O',
#  'O=CCO))CO)CO)CO)CO)COP=O)O)O',
#  'O=CCO)CO)))CO)CO)COP=O)O)O',
#  'O=CO)C=O)CO)CO)CO)CO',
#  'NCC=O)O))CO)CO)CO)COP=O)O)O',
#  'CC=O)C=O)O',
#  'O=CO)CCC=O)C=O)O',
#  'O=cccnCOCCOP=O)O)OP=O)O)OCOCCO))CO)CO)C6O)))))))))))))CO)C5O))))))c=O)[nH]6',
#  'O=PO)O)OCOCCO))CO)CO)C6O',
#  'O=CCO))COP=O)O)O',
#  'OCCO)CO',
#  'O=CO)COCOP=O)O)OP=O)O)OCCOCnccc=O)[nH]c6=O)))))))CO)C5O))))))))))))CO)CO)C6O',
#  'OCCOCO)CO)C6O',
#  'O=CO)COCO)CO)CO)C6O',
#  'O=CCO))CO)CO)COP=O)O)O',
#  'O=CO)C=O)CCO)CO)CO',
#  'O=CCO))CO)CO)COP=O)O)O',
#  'OCCOCO)CO)C6O',
#  'O=CCO',
#  'OCCO)OCCO)C5O',
#  'OCCO)OCCO)C5O',
#  'OCCO)OCCO)C5O',
#  'O=CO)COCO)CO)CO)C6O',
#  'OCCO)CO)CO)CO',
#  'O=CCCC=O)C=O)O',
#  'OCCO)CO)CO)CO',
#  'OCCOCO)CO)C6O',
#  'O=CO)CO)CO)CO)CO',
#  'OCCO)OCCO)C5O',
#  'O=CO)CO)CO)CO)CO)CO',
#  'OCCO)CO)CO)CO',
#  'O=CO)COCO)CO))CO)C5O',
#  'O=CO)CO)C=O)CO)CO)CO',
#  'NcccnCOCCOP=O)O)OP=O)O)OCCO)CO)CO)CO))))))))))))CO)C5O))))))c=O)n6',
#  'O=CO)CO)CO)CO)CO)CO',
#  'O=CO)CO)CO)CO)CO)CO',
#  'O=CO)COCO)CO))CO)C5O',
#  'O=PO)O)OCCO)CO)CO)CO',
#  'O=CCO))CO)CO)COP=O)O)O',
#  'OCCOCO)CO)C6O',
#  'OCCO)CO)CO)CO',
#  'O=COCCO)CO)C6O',
#  'O=CO)COCOCCC=O)O))OCO)CO)C6O))))))))CO)CO)C6O',
#  'O=CCO)CO',
#  '[*]OCOCC=O)O))CO)CO)C6O',
#  'O=CCO))CO)CO)COP=O)O)O',
#  'O=CO)C=O)CCO)CO',
#  'O=CCO)CO)CC=O)C=O)O',
#  'O=CO)C=O)CCO)C=O)CO',
#  'O=CO)C=O)C=O)CO)CO)CO',
#  'O=CO)COCOP=O)O)O)))CO)CO)C6O',
#  'O=CO)CO)CO)CO)CO',
#  'O=CO)CO)CO)CO)CO',
#  'O=CO)C=CCO)CO)COCCC=O)O))OCO)CO)C6O))))))))O6',
#  'O=PO)O)OCCO)OCCO)C5O',
#  'O=CO)CO)C=O)CO)CO)COP=O)O)O',
#  'O=CO)CO)CO)CO)CO)CO',
#  'O=CO)C=O)CCO)CO)CO',
#  'OCCOCO)CO))CO)C5O',
#  'Ncnccncn5COCCOP=O)O)OP=O)O)OCOCCO))CO)CO)C6O)))))))))))))CO)C5O)))))))))c=O)[nH]6',
#  'O=CCO))COP=O)O)O',
#  'O=CCO)COP=O)O)O',
#  'OCCOCO)CO)CO)C6O',
#  'CCO)C=O)O',
#  'OCCO)OCCO)CO)C6O',
#  'OCCOCO)CO)CO)C6O',
#  'O=PO)O)OCCOCO)CO)CO)C6O',
#  'CCOCOP=O)O)OP=O)O)OCCOCncncc=O)[nH]cN)nc69)))))))))CO)C5O))))))))))))CO)CO)C6O',
#  'OCCO)CO)CO)CO)CO',
#  'CCO)C=O',
#  'CCOCO)CO)CO)C6O',
#  'O=CCO)CO',
#  'O=PO)O)OCOCCO))CO)CO)C6O',
#  'O=PO)O)OCCO)CO)CO)CO)CO',
#  'O=PO)O)OCCOCCO))OP=O)O)O)))CO)C5O',
#  'OCCO)CO)CO)CO)CO',
#  'CCO)CO)CO)C=O)CO',
#  'Ncnccncn5COCCOP=O)O)OP=O)O)OCOCC=O)O))CO)CO)C6O)))))))))))))CO)C5O)))))))))c=O)[nH]6',
#  'CCOCO)CO)CO)C6O',
#  'O=PO)O)OCCO)OCCO))CO)C5O',
#  'O=PO)O)OCCO)CO)CO)CO)CO',
#  'CCO)CO)CO)C=O)COP=O)O)O',
#  'CCO)CO)CO)C=O)COP=O)O)O',
#  'CCOCOP=O)O)OP=O)O)OCCOCncncc=O)[nH]cN)nc69)))))))))CO)C5O))))))))))))CO)CO)C6=O',
#  'OCCOCO)CO)CO)C6O',
#  'CCO)CO)CO)CO)C=O)O',
#  'CCO)CO)CO)C=O)CO',
#  'CCO)CO)CO)CO)C=O)O',
#  'CCO)COCO)CO)C5O',
#  'O=CCOP=O)O)O))))CO)CO)CO)CO',
#  'O=PO)O)OCCOCO)CO)CO)C6O',
#  'CCOCOP=O)O)OP=O)O)OCCOCncncc=O)[nH]cN)nc69)))))))))CO)C5O))))))))))))CO)CO)C6O',
#  'CCOCOP=O)O)O)))CO)CO)C6O',
#  'CCO)COC=O)CO)C5O',
#  'CCOCOP=O)O)OP=O)O)OCCOCncncc=O)[nH]cN)nc69)))))))))CO)C5O))))))))))))CO)CO)C6O',
#  'O=PO)O)OCCO))OCCO))CO)C5O',
#  'CCO)CO)CC=O)C=O)O',
#  'CCO)CO)CC=O)C=O)O',
#  'O=PO)O)OCCOCO)CO))CO)C5O',
#  'O=PO)O)OCCOCO)COP=O)O)O))))CO)C5O',
#  'Ncncncc6ncn5COCCOP=O)O)OP=O)O)OCOCCO))CO)CO)C6O)))))))))))))CO)C5O',
#  'O=CO)CCOP=O)O)O))))OCOCCO))CO)CO)C6O',
#  'O=CO)CCO))OCOCCO))CO)CO)C6O',
#  'CCOC=O)CO)CO)C6O',
#  'O=PO)O)OCCOCO)CO))CO)C5O',
#  'CCO)C=O)CC=O)C=O)O',
#  'O=cccnCOCCOP=O)O)OP=O)O)OCOCCO))CO)CO)C6O)))))))))))))CO)C5O))))))c=O)[nH]6',
#  'OCCOCO)CO)CO)C6O',
#  'O=cccnCOCCOP=O)O)OP=O)O)OCOCCO))CO)CO)C6O)))))))))))))CO)C5O))))))c=O)[nH]6',
#  'O=PO)O)OCCOCO)CO))CO)C5O',
#  'OCCOCOCCO))OCCO))CO)C5O)))))))CO)CO)C6O',
#  'OCCOCO)CO))CO)C5O',
#  'O=PO)O)OCOCCO))CO)CO)C6O',
#  'O=CCO))COP=O)O)O',
#  'OCCO)CO',
#  'O=CCO)COP=O)O)O',
#  'OCCOCO)CO)CO)C6O',
#  'OCCO)CO)CO)CO)C6O',
#  'OCCOCO)CO)CO)C6O',
#  'OCCOCOCCCO))OCO)CO)C6O))))))))CO)CO)C6O',
#  'OCCOCO)CO)CO)C6O',
#  'O=PO)O)OCOCCO))CO)CO)C6O',
#  'OCCOCOCCOCOCCO))OCCO))CO)C5O)))))))CO)CO)C6O)))))))))CO)CO)C6O',
#  'O=CCO)CO',
#  'O=PO)O)OCCOCO)CO)CO)C6O',
#  'OCCO)CO)CO)CO)CO',
#  'OCCO)OCCO)CO)C6O',
#  'O=CO)CO)CO)CO)CO)CO',
#  'OCCOCO)CO)CO)C6O',
#  'O=PO)O)OCCOCO)CO))CO)C5O',
#  'O=PO)O)OCCOCO)CO)CO)C6O',
#  'CC=O)NCCO)OCCO))CO)C6O',
#  'O=CO)C=O)CCO)CO)CO',
#  'OCCOCOCCO)CO)CO)CO)C6O))))))))CO)CO)C6O',
#  'O=CO)C=O)CCO)CO)COP=O)O)O',
#  'OCCOCOCCOCOCCOCOCCO))OCCO))CO)C5O)))))))CO)CO)C6O)))))))))CO)CO)C6O)))))))))CO)CO)C6O',
#  'OCCO)CO)CO)CO)CO',
#  'NCCO)OCCO))CO)C6O',
#  'O=COCCO))CO)CO)C6O',
#  'O=COCCO)CO)))CO)C5O',
#  'O=cccnCOCCOP=O)O)OP=O)O)OCOCCO)CO)))CO)C5O))))))))))))CO)C5O))))))c=O)[nH]6',
#  'O=PO)O)OCCOCO)COP=O)O)O))))CO)C5O',
#  'O=PO)O)OCCOCOCCCO))OCO)CO)C6O))))))))CO)CO)C6O',
#  'OCCO)CO)CO)CO)COCOCCO))CO)CO)C6O',
#  'OCCOCOCCOCO)CO)CO)C6O)))))))))CO)CO)C6O',
#  'OCCO)COCOCCO))CO)CO)C6O',
#  'OCCOCOCCOCO)CO)CO)C6O)))))))))CO)CO)C6O',
#  'OCCOCOCCOCOCCOCO)CO)CO)C6O)))))))))CO)CO)C6O)))))))))CO)CO)C6O',
#  'O=PO)O)OCCO)CO)CO)CO)CO',
#  'CC=O)NCCO)OCCOP=O)O)O))))CO)C6O',
#  'NCCO)OCCOP=O)O)O))))CO)C6O',
#  'CC=O)C=O)O',
#  'O=CO)CCC=O)C=O)O',
#  'O=cccnCOCCOP=O)O)OP=O)O)OCOCCO))CO)CO)C6O)))))))))))))CO)C5O))))))c=O)[nH]6',
#  'O=COCCO)CO)))CO)=C5O',
#  'Ncnccncn5COCCOP=O)O)OP=O)O)OCOCCO))CO)CO)C6O)))))))))))))CO)C5O)))))))))c=O)[nH]6',
#  'OCCO)CO)CO)CO)C6O',
#  'O=CO)COCOP=O)O)OP=O)O)OCCOCnccc=O)[nH]c6=O)))))))CO)C5O))))))))))))CO)CO)C6O',
#  'O=CO)COCO)CO)CO)C6O',
#  'O=CCO))CO)CO)COP=O)O)O',
#  'OCCOCO)CO)C6O',
#  'O=CO)COCO)CO)CO)C6O',
#  'O=CCCC=O)C=O)O',
#  'O=CO)CO)CO)CO)CO',
#  'O=CO)CO)C=O)CO)CO)CO',
#  'O=CO)C=O)CCO)CO)C=O)O',
#  'O=CO)C=O)CCO)CO',
#  'O=CO)CO)CO)CO)CO)CO',
#  'O=CO)CO)CO)CO)CO)C=O)O',
#  'O=CO)CO)CO)CO)CO)C=O)O',
#  'O=COCCO)CO)))CO)C5O',
#  'O=CCO))CO)CO)COP=O)O)O',
#  'O=COCCO))CO)C5O',
#  'O=COCCO)CO)))CO)C5O',
#  'O=CCO)C=O)O',
#  'O=CO)CO)CO)CO',
#  'OCCOCO)CO)CO)C6O',
#  'Ncnccncn5COCCOP=O)O)OP=O)O)OCOCCO))CO)CO)C6O)))))))))))))CO)C5O)))))))))c=O)[nH]6',
#  'O=CCO)COC=O)CO)C5O',
#  'O=CO)CO)C=O)CO',
#  'O=COCCO)CO)))CO)C5=O',
#  'O=CCO))CO)CO)COP=O)O)O',
#  'O=CO)C=O)CCO)CO)C=O)O',
#  'O=CO)C=O)C=O)CO)CO)CO',
#  'O=CO)COCOP=O)O)O)))CO)CO)C6O',
#  'O=CO)CO)CO)CO)CO',
#  'O=CO)CO)CO)CO)CO',
#  'O=COCCO)CO)))C=O)C5=O',
#  'O=CO)CO)C=O)CO)CO)COP=O)O)O',
#  'OCCOCO)CO)CO)C6O',
#  'O=PO)O)OCOCCO))CO)CO)C6O',
#  'Ncnccncn5COCCOP=O)O)OP=O)O)OCOCCO))CO)CO)C6O)))))))))))))CO)C5O)))))))))c=O)[nH]6',
#  'O=PO)O)OCOCCO))CO)CO)C6O',
#  'O=CO)CO)CO)CO)CO)CO',
#  'O=COCCO)COP=O)O)O)))))CO)=C5O',
#  'O=COCC=O)O))CO)CO)C6O',
#  'O=COCCO)C=O)O)))CO)C5O',
#  'O=cccnCOCCOP=O)O)OP=O)O)OCOCCO))CO)CO)C6O)))))))))))))CO)C5O))))))c=O)[nH]6',
#  'OCCOCO)CO)CO)C6O',
#  'O=PO)O)OCCOCO)CO))CO)C5O',
#  'OCCOCOCCO))OCCO))CO)C5O)))))))CO)CO)C6O',
#  'O=PO)O)OCCOCO)CO)CO)C6O',
#  'OCCOCO)CO))CO)C5O',
#  'O=PO)O)OCOCCO))CO)CO)C6O',
#  'OCCOCOCCCO))OCO)CO)C6O))))))))CO)CO)C6O',
#  'OCCOCOCCCO))OCO)CO)C6O))))))))CO)CO)C6O',
#  'OCCOCOCCOCO)CO)CO)C6O)))))))))CO)CO)C6O',
#  'Ncnccncn5COCCOP=O)O)OP=O)O)OCOCCO))CO)CO)C6O)))))))))))))CO)C5O)))))))))c=O)[nH]6',
#  'Ncncncc6ncn5COCCOP=O)O)OP=O)O)OCOCCO))CO)CO)C6O)))))))))))))CO)C5O',
#  'NcccnCOCCOP=O)O)OP=O)O)OCOCCO))CO)CO)C6O)))))))))))))CO)C5O))))))c=O)n6',
#  'O=PO)O)OCOCCO))CO)CO)C6O',
#  'O=PO)O)OCCOCOCOCCO))CO)CO)C6O))))))))CO)CO)C6O',
#  '[*]OCOCCO))CO)CO)C6O',
#  'OCCOCOCOCCO))CO)CO)C6O))))))))CO)CO)C6O',
#  'O=PO)O)OCCOCOP=O)O)O)))CO)CO)C6O',
#  'OCCOCCO))OCCOCO)CO))CO)C5O))))))))CO)C5O',
#  'O=PO)O)OCCOCCO))OCOCCO))CO)CO)C6O))))))))CO)C5O',
#  'O=PO)O)OCCOCOCCCO))OCO)CO)C6O))))))))CO)CO)C6O',
#  'O=PO)O)OCCOCOCCCO))OCO)CO)C6O))))))))CO)CO)C6O',
#  'O=CCO)CCO))OCOCCO))OCCO))CO)C5O)))))))C6O',
#  'O=PO)O)OCCOCOCCO))OCCO))CO)C5O)))))))CO)CO)C6O',
#  'O=PO)O)OCOCCO))COCOCCO))CO)CO)C6O))))))))CO)C6O',
#  'O=cccnCOCCOP=O)O)OP=O)O)OCOCCO))CO)CO)C6O)))))))))))))CO)C5O))))))c=O)[nH]6',
#  'OCCOCO)CO)CO)C6O',
#  'CC=O)NCCOP=O)O)OP=O)O)OCCOCnccc=O)[nH]c6=O)))))))CO)C5O))))))))))))OCCO))CO)C6O',
#  'O=cccnCOCCOP=O)O)OP=O)O)OCOCCO))CO)CO)C6O)))))))))))))CO)C5O))))))c=O)[nH]6',
#  'Ncnccncn5COCCOP=O)O)OP=O)O)OCOCCO))CO)CO)C6O)))))))))))))CO)C5O)))))))))c=O)[nH]6',
#  'O=PO)O)OCOCCO))CO)CO)C6O',
#  'CC=O)NCCO)CCOP=O)O)OCCOCncccN)nc6=O)))))))CO)C5O))))))))))C=O)O))OC6CO)CO)CO',
#  'CC=O)NCCO)OCCO))CO)C6O',
#  'OCCOCO)CO)CO)C6O',
#  'O=CO)COCOP=O)O)OP=O)O)OCCOCnccc=O)[nH]c6=O)))))))CO)C5O))))))))))))CO)CO)C6O',
#  'OCCOCO)CO)C6O',
#  'O=cccnCOCCOP=O)O)OP=O)O)OCOCCO)CO)C6O)))))))))))))CO)C5O))))))c=O)[nH]6',
#  'O=CO)COCO)CO)CO)C6O',
#  'CC=O)NCCOP=O)O)OP=O)O)OCCOCnccc=O)[nH]c6=O)))))))CO)C5O))))))))))))OCCO))CO)C6O',
#  'OCCOCO)CO)C6O',
#  'OCCOCO)CO)CO)C6O',
#  'CC=O)NCCO)CCO)C=O)O))OC6CO)CO)CO',
#  'O=PO)O)OCCOCO)CO)CO)C6O',
#  'CCOCOP=O)O)OP=O)O)OCCOCncncc=O)[nH]cN)nc69)))))))))CO)C5O))))))))))))CO)CO)C6O',
#  'NCCO)OCCO))CO)C6O',
#  'O=CO)COCO)CO)CO)C6O',
#  'NCCO)OCCOP=O)O)O))))CO)C6O',
#  'CC=O)NCCO)OCCOP=O)O)O))))CO)C6O',
#  'Ncnccncn5COCCOP=O)O)OP=O)O)OCOCCO))CO)CO)C6O)))))))))))))CO)C5O)))))))))c=O)[nH]6',
#  'O=PO)O)OCOCCO))CO)CO)C6O',
#  'Ncncncc6ncn5COCCOP=O)O)OP=O)O)OCOCCO))CO)CO)C6O)))))))))))))CO)C5O',
#  'NcccnCOCCOP=O)O)OP=O)O)OCOCCO))CO)CO)C6O)))))))))))))CO)C5O))))))c=O)n6',
#  'O=CO)COCOP=O)O)OP=O)O)OCCOCnccc=O)[nH]c6=O)))))))CO)C5O))))))))))))CO)CO)C6O',
#  'O=PO)O)OCOCCO))CO)CO)C6O',
#  'CC=O)NCCO)OCCO))CO)C6O',
#  'O=PO)O)OCCOCO)CO)CO)C6O',
#  'O=cccnCOCCOP=O)O)OP=O)O)OCOCCO)CO)C6O)))))))))))))CO)C5O))))))c=O)[nH]6',
#  'Ncnccncn5COCCOP=O)O)OP=O)O)OCOCC=O)O))CO)CO)C6O)))))))))))))CO)C5O)))))))))c=O)[nH]6',
#  'OCCOCO)CO)CO)C6O',
#  'CCOCO)CO)CO)C6O',
#  'CC=O)NCCOP=O)O)OP=O)O)OCCOCnccc=O)[nH]c6=O)))))))CO)C5O))))))))))))OCCO))CO)C6OCC)C=O)O',
#  'CC=O)NCCOP=O)O)OP=O)O)OCCOCnccc=O)[nH]c6=O)))))))CO)C5O))))))))))))OCCO))CO)C6O',
#  'CCOCOP=O)O)OP=O)O)OCCOCncccN)nc6=O)))))))CO)C5O))))))))))))CO)CO)C6=O',
#  'CCOCOP=O)O)OP=O)O)OCCOCncncc=O)[nH]cN)nc69)))))))))CO)C5O))))))))))))CO)CO)C6=O',
#  'O=cccnCOCCOP=O)O)OP=O)O)OCOCCO)CO))C5O))))))))))))CO)C5O))))))c=O)[nH]6',
#  'CC=O)NCCO)OCCO))COCOCCO))CO)CO)C6NCC)=O))))))))))C6O',
#  'CCOCOP=O)O)OP=O)O)OCCOCncccN)nc6=O)))))))CO)C5O))))))))))))CO)CC6O',
#  'CCOCOP=O)O)OP=O)O)OCCOCnccc=O)[nH]c6=O)))))))CO)C5O))))))))))))CO)CO)C6O',
#  'Ncnccncn5COCCOP=O)O)OP=O)O)OCOCCO))CO)CO)C6O)))))))))))))CO)C5O)))))))))c=O)[nH]6',
#  'O=CO)COCOP=O)O)OP=O)O)OCCOCnccc=O)[nH]c6=O)))))))CO)C5O))))))))))))CO)CO)C6O',
#  'OCCOCO)CO))CO)C5O',
#  'CC=O)NCCO)OCCO))CO)C6OCC)C=O)O',
#  'CCOCOP=O)O)OP=O)O)OCCOCncncc=O)[nH]cN)nc69)))))))))CO)C5O))))))))))))CO)CO)C6O',
#  'CCOCOP=O)O)O)))CO)CO)C6O',
#  'CCOCOP=O)O)OP=O)O)OCCOCncncc=O)[nH]cN)nc69)))))))))CO)C5O))))))))))))CO)CO)C6O',
#  'O=CCO))NCCO)CCO)C=O)O))OC6CO)CO)CO',
#  'CCOCOP=O)O)OP=O)O)OCCOCncccN)nc6=O)))))))CO)C5O))))))))))))CO)CC6O',
#  'CCOCOP=O)O)OP=O)O)OCCOCncccN)nc6=O)))))))CO)C5O))))))))))))CO)CC6O',
#  'NcccnCOCCOP=O)O)OCC=O)O))CCO)CNC=O)CO))))CCO)CO)CO))))O6))))))))))CO)C5O))))))c=O)n6',
#  'O=cccnCOCCOP=O)O)OP=O)O)OCOCCO)CO)))CO)C5O))))))))))))CO)C5O))))))c=O)[nH]6',
#  'O=PO)O)OCOCCO)CO)C6O',
#  'O=CO)COCOP=O)O)O)))CO)CO)C6O',
#  'CCOCOP=O)O)OP=O)O)OCCOCnccc=O)[nH]c6=O)))))))CO)C5O))))))))))))CO)CO)C6=O',
#  'CC=O)NCCO)OCCOP=O)O)O))))CO)C6O',
#  'CCOCOP=O)O)OP=O)O)OCCOCncccN)nc6=O)))))))CO)C5O))))))))))))CO)CC6=O',
#  'CC=O)NCCOP=O)O)O)))OCCO))CO)C6O',
#  'CC=O)NCCOP=O)O)OP=O)O)OCCOCnccc=O)[nH]c6=O)))))))CO)C5O))))))))))))OCC=O)O))CO)C6O',
#  'CC=O)NCCOP=O)O)OP=O)O)OCCOCnccc=O)[nH]c6=O)))))))CO)C5O))))))))))))OCC)C=O)C6O',
#  'CC=O)NCCOP=O)O)OP=O)O)OCCOCnccc=O)[nH]c6=O)))))))CO)C5O))))))))))))OCC)CN)C6O',
#  'C=COCCO)CCO))OCOP=O)O)OP=O)O)OCCOCnccc=O)[nH]c6=O)))))))CO)C5O))))))))))))C6NCC)=O))))))))))C=O)O',
#  'O=PO)O)OCCOCO)CO))CO)C5O',
#  'O=CO)COCOP=O)O)O)))CO)CO)C6O',
#  'NCCOP=O)O)O)))OCCO))CO)C6O',
#  'CC=O)NCCOP=O)O)OP=O)O)OCCOCnccc=O)[nH]c6=O)))))))CO)C5O))))))))))))OCC=O)O))CO)C6O',
#  'CC=O)NCCO)CCO)C=O)O))OC6CO)CO)COP=O)O)O',
#  'O=cccnCOCCOP=O)O)OP=O)O)OCOCCS=O)=O)O)))CO)CO)C6O)))))))))))))CO)C5O))))))c=O)[nH]6',
#  'CC=O)NCCOP=O)O)OP=O)O)OCCOCnccc=O)[nH]c6=O)))))))CO)C5O))))))))))))OCC=O)O))CO)C6O',
#  'Ncnccncn5COCCOP=O)O)OP=O)O)OCOCCO))CO)CO)C6O)))))))))))))CO)C5O)))))))))c=O)[nH]6',
#  'NCCOCOP=O)O)OP=O)O)OCCOCnccc=O)[nH]c6=O)))))))CO)C5O))))))))))))CO)C6O',
#  'O=CNCCOCOP=O)O)OP=O)O)OCCOCnccc=O)[nH]c6=O)))))))CO)C5O))))))))))))CO)C6O',
#  'O=CCOCOP=O)O)OP=O)O)OCCOCnccc=O)[nH]c6=O)))))))CO)C5O))))))))))))CO)C6O',
#  'CCC)=CCCCC)=CCCCC)=CCCCC)=CCCCC)=CCCCC)=CCCCC)=CCCCC)=CCCCC)=CCCCC)=CCCCC)=CCOP=O)O)OCOCCNC=O)))CO)C6O',
#  'CCC)=CCCCC)=CCCCC)=CCCCC)=CCCCC)=CCCCC)=CCCCC)=CCCCC)=CCCCC)=CCCCC)=CCCCC)=CCOP=O)O)OCOCCN)CO)C6O',
#  'CC=O)NCCO)OCCOP=O)O)O))))CO)C6OCC)C=O)O',
#  'CCOCOP=O)O)OP=O)O)OCCOCncccN)nc6=O)))))))CO)C5O))))))))))))CO)CC6=O',
#  'CCOCOP=O)O)OP=O)O)OCCOCncccN)nc6=O)))))))CO)C5O))))))))))))CO)CC6O',
#  'CCOCOP=O)O)OP=O)O)OCCOCnccc=O)[nH]c6=O)))))))CO)C5O))))))))))))CO)CO)C6=O',
#  'O=cccnCOCCOP=O)O)OP=O)O)OCOCCO))CO)C5O))))))))))))CO)C5O))))))c=O)[nH]6',
#  'CC=O)NCCOP=O)O)OP=O)O)OCCOCnccc=O)[nH]c6=O)))))))CO)C5O))))))))))))OCC=O)O))CO)C6NCC)=O',
#  'CC=O)NCCOP=O)O)OP=O)O)OCCOCnccc=O)[nH]c6=O)))))))CO)C5O))))))))))))OCC=O)O))CO)C6NCC)=O',
#  'CC=O)NCCOP=O)O)OP=O)O)OCCOCnccc=O)[nH]c6=O)))))))CO)C5O))))))))))))OCC)C=O)C6O',
#  'CC=O)NCCOP=O)O)OP=O)O)OCCOCnccc=O)[nH]c6=O)))))))CO)C5O))))))))))))OCC)CN)C6O',
#  'CC=O)NCCC)OCOP=O)O)OP=O)O)OCCOCnccc=O)[nH]c6=O)))))))CO)C5O))))))))))))CNCC)=O)))C6O',
#  'CC=O)NCCC)OCO)CNCC)=O)))C6O',
#  'CC=O)NCCC)O))COCO)C=O)O))CCO)C6NCC)=O',
#  'CC=O)NCCC)O))COCOP=O)O)OCCOCncccN)nc6=O)))))))CO)C5O))))))))))C=O)O))CCO)C6NCC)=O',
#  'CC=O)NCCC)OCOP=O)O)OP=O)O)OCCOCnccc=O)[nH]c6=O)))))))CO)C5O))))))))))))CNCC)=O)))C6O',
#  'CC=O)NCCOP=O)O)OP=O)O)OCCOCnccc=O)[nH]c6=O)))))))CO)C5O))))))))))))OCC=O)O))CO)C6N',
#  'CC=O)NCC=O)CO)CC=O)O))OC6OP=O)O)OP=O)O)OCCOCnccc=O)[nH]c6=O)))))))CO)C5O',
#  'CC=O)NCCC)O))COCO)C=O)O))CCO)C6NCC)=O',
#  'CC=O)NCCC)O))COCOP=O)O)OCCOCncccN)nc6=O)))))))CO)C5O))))))))))C=O)O))CCO)C6NCC)=O',
#  'CC=O)NCCC)OCO)CNCC)=O)))C6O',
#  'CCOCOP=O)O)OP=O)O)OCCOCncncc=O)[nH]cN)nc69)))))))))CO)C5O))))))))))))CO)CO)C6N',
#  'CC=O)NCCC)OCOP=O)O)OP=O)O)OCCOCncncc=O)[nH]cN)nc69)))))))))CO)C5O))))))))))))CO)C6O',
#  'CC=O)NCCOP=O)O)O)))OCCO))CO)C6OCC)C=O)O',
#  'CC=O)C=O)O',
#  'CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CC=O)O',
#  'O=CO)CC=O)C=O)O',
#  'O=CO)CCC=O)O',
#  'O=CO',
#  'CcnccC[n+]cscCCOP=O)O)OP=O)O)O)))))))c5C)))))))cN)n6',
#  'C=COP=O)O)O)))C=O)O',
#  'CCC)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O)))))))))))))))CO)C=O)NCCC=O)NCCSC=O)CC=O)O',
#  'CC=O',
#  'O=CO)C=CC=O)O',
#  'O=CO)CCO)C=O)O',
#  'CCO)C=O)O',
#  'CC=O)OP=O)O)O',
#  'CCO)C=O)O',
#  'CC=O)CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCO)C=O',
#  'CC=O)C=O',
#  'CCO)C=O',
#  'O=CO)CCCO)CC=O)O)))C=O)O',
#  'CCCO)CC=O)O)))C=O)O',
#  'CCC)CO)CC=O)O)))C=O)O',
#  'O=CO)C#CC=O)O',
#  'CCO)C=O)SCCNC=O)CCCN)C=O)O)))))))C=O)NCC=O)O',
#  'O=CO)C=CO)C=O)O',
#  'CcnccC[n+]cCC)O))scCCOP=O)O)OP=O)O)O)))))))c5C)))))))cN)n6',
#  'CC=O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5O',
#  'CCCCO)CC=O)O)))C=O)O',
#  '[*]NC=O)CCCCCCCSS5',
#  '[*]NC=O)CCCCCS)CCS',
#  '[*]NC=O)CCCCCS)CCSCC)=O',
#  'O=O',
#  'O=C=O',
#  'N',
#  'CC=O)C=O)O',
#  'CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'NCCCC=O)O))))C=O)O',
#  'O=CO)CCC=O)C=O)O',
#  'OO',
#  'CC=O)O',
#  'O=CO)CC=O)C=O)O',
#  'NCC=O)O',
#  'O=CO)CCC=O)O',
#  'O=CC=O)O',
#  'O=CO',
#  'NC=O)CCCN)C=O)O',
#  'NCCO))C=O)O',
#  'CCC)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O)))))))))))))))CO)C=O)NCCC=O)NCCSC=O)CCC=O)O',
#  'CCC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCCC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'O=CO)CCO)C=O)O',
#  'O=CO)CCO)CC=O)O)))C=O)O',
#  'O=CO)CO',
#  'O=CO)C=O)CO',
#  'O=CO)CO)COP=O)O)O',
#  'O=CO)C=O)O',
#  'O=CO)CO)CO',
#  'O=CCO',
#  'O=CO)CCC=O)O))CO)C=O)O',
#  'CCC)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O)))))))))))))))CO)C=O)NCCC=O)NCCSC=O)C=O)O',
#  'CC=O)CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'O=CO)C=CCC=O)O)))C=O)O',
#  'O=CO)CO)CO)C=O)O',
#  'O=CO)CCO))OP=O)O)O',
#  'CCC=O)O))C=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCC)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O)))))))))))))))CO)C=O)NCCC=O)NCCSC=O',
#  'CC=CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCCCC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'O=CO)CO)CO)C=O)O',
#  'O=CO)CO)=CO)C=O)O',
#  'O=CO)COP=O)O)O',
#  'O=CO)C=O)CCO)C=O)O',
#  'O=CCO)C=O)O',
#  'O=CCOP=O)O)O))))CO)CO)COP=O)O)O',
#  'CCC=O)O))C=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'OCCO',
#  'CC=CC=O)O)))C=O)O',
#  'CCCC=O)O))CO)C=O)O',
#  'O=CO)C=O)CC=O)O))CO)C=O)O',
#  'CCCCC=O)O))CO)C=O)O',
#  'O=COP=O)O)O',
#  'O=CO)CCC=O)CO)C=O)O',
#  'O=CO)C=O)CO)C=O)O',
#  'O=CO)COC3C=O)O',
#  'CCO)CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCC=O)O))CN)C=O)O',
#  'CCC)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O)))))))))))))))CO)C=O)NCCC=O)NCCSC=O)CCO)C=O)O',
#  'CCC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O)))))))))))))))))))))))))))CO)C=O)O',
#  'CC=CC=O)O)))C=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  '[*]NC=O',
#  'CCCC=O)O))C=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCCC=O)O)))C=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCCC=O)O))C=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CC=O)O',
#  'O=CO)CCC=O)O',
#  'CcnccC[n+]cscCCOP=O)O)OP=O)O)O)))))))c5C)))))))cN)n6',
#  'CCC)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O)))))))))))))))CO)C=O)NCCC=O)NCCSC=O)CC=O)O',
#  'CCC)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O)))))))))))))))CO)C=O)NCCC=O)NCCSC=O)CCC=O)O',
#  'NCCC=O)O',
#  'CCC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCC=O)C=O)O',
#  'O=CCO))COP=O)O)O',
#  'CO',
#  'CCC=O)O',
#  'CC=O)CC=O)O',
#  'CCO)C=O)O',
#  'CCC)=O',
#  'O=CCC=O)O',
#  'CC=O)CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCO)C=O',
#  'CCC=O',
#  'CC=O)C=O',
#  'CCO)CO',
#  'CCC=O)O))C=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'C#CC=O)O',
#  'CCO)C=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'C=CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'O=CO)CCO',
#  'CCC=O)O))C=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCC)O',
#  'CCC=O)O))C=O)O',
#  'CCC=O)O))CO)CC=O)O)))C=O)O',
#  'CCC)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O)))))))))))))))CO)C=O)NCCC=O)NCCSC=O)CCN',
#  'CCC=O)OP=O)O)O',
#  'CCC=O)O))=CCC=O)O)))C=O)O',
#  'CCO)C=O)O))CCC=O)O)))C=O)O',
#  'CC=O)CO',
#  'CCC)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O)))))))))))))))CO)C=O)NCCC=O)NCCSC=O)CCO',
#  'CCCO',
#  'CCC=O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5O',
#  'CCCO)C=O)O',
#  'CCC)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O)))))))))))))))CO)C=O)NCCC=O)NCCSC=O)CC=O',
#  'CCC=O))C=O)O',
#  '[*]NC=O)CCCCCCCSS5',
#  '[*]NC=O)CCCCCS)CCS',
#  'COCC)=O',
#  'CCC',
#  'CCCO)cscCCOP=O)O)OP=O)O)O)))))))cC)[n+]5CccncC)nc6N',
#  '[*]NC=O)CCCCCS)CCSC=O)CC',
#  'CCC=O)O))=CCC=O)O)))C=O)O',
#  'CC=O)C=O)O',
#  'CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'NCCCC=O)O))))C=O)O',
#  'O=CO)CCC=O)C=O)O',
#  'O=CO)CCC=O)O',
#  'CCC)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O)))))))))))))))CO)C=O)NCCC=O)NCCSC=O)CCC=O)O',
#  'O=CO)C=CC=O)O',
#  'CCCC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CC=O)CC=O)O',
#  'O=CCCC=O)O',
#  'CCCC=O)O',
#  'CC=O)CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'NCCCC=O)O',
#  'CCO)CC=O)O)))CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'O=CO)CCO)C=O)O',
#  'CC=O)CC)=O',
#  'CC=O)CC)O',
#  'CC=CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'O=CO)CCCO',
#  'CCO)CC=O)O',
#  'CCO)CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'O=CO)C=CC=O)O',
#  'CCCC=O',
#  'CC=O)CC)O',
#  'C=CCC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCC)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O)))))))))))))))CO)C=O)NCCC=O)NCCSC=O)C=CCC=O)O',
#  'CCCC=O)OP=O)O)O',
#  'O=CO)CCCO)C=O)O',
#  'CCO)CC)O',
#  'CCO)CC)O',
#  'CCC)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O)))))))))))))))CO)C=O)NCCC=O)NCCSC=O)CO)CCC=O)O',
#  'CCO)CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCO)CC=O)OCC)CC=O)O',
#  'CC=O)CC)O)C=O)O',
#  'CCCCO',
#  'C#CCC=O)O',
#  'C#CCC=O',
#  'C#CCCO',
#  'CCC)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O)))))))))))))))CO)C=O)NCCC=O)NCCSC=O)CCCO',
#  'CCO)CC)O',
#  'CCCC',
#  'CC=O)C=O)O',
#  'NCCCC=O)O))))C=O)O',
#  'O=CO)CCC=O)C=O)O',
#  'CC=O)O',
#  'O=CC=O)O',
#  'CCC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCC=O)C=O)O',
#  'O=CO)C=CCC=O)O)))C=O)O',
#  'C=CCC=O)O)))C=O)O',
#  'C=CCC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O))))))))))))))))))))))))))))C=O)O',
#  'C=CCCN)C=O)O))))C=O)O',
#  'CC=O)CC)O',
#  'CCO)CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O))))))))))))))))))))))))))))C=O)O',
#  'C=CCCN)C=O)O))))CN)=O',
#  'CC=CC=O)O)))C=O)O',
#  'CC=CC=O)O)))C=O)O',
#  'O=CO)C=CCC=O)O)))C=O)O',
#  'CCO)CC=O)O)))C=O)O',
#  'CCO)CC=O)O)))C=O)O',
#  'O=CO)CCCO)C=O)O',
#  'CCC=O)OP=O)O)O',
#  'CCC=O)O))CN)C=O)O',
#  'CC=O)CC)O)C=O)O',
#  'CCC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O)))))))))))))))))))))))))))CO)C=O)O',
#  'CC=CC=O)O)))C=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCC=O)O))CO)C=O)O',
#  'CCC=O)O))C=O)C=O)O',
#  'CCC=O)O))CO)C=O)O',
#  'CCC=O)O))CO)C=O)O',
#  'CCO)CC=O)C=O)O))))C=O)O',
#  'CCO)CCN)C=O)O))))C=O)O',
#  'C=CCC=O)C=O)O))))C=O)O',
#  'CCCCN)C=O)O))))C=O)O',
#  'O=CCCO)C=O)O))CO5',
#  'CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'O=PO)O)OCCOCO)CO)CO)C6O',
#  'O=CCO))COP=O)O)O',
#  'O=CCO)COP=O)O)O',
#  'OCCO)CO)CO)CO)C6O',
#  'O=CO)COCO)CO)CO)C6O',
#  'O=CCC=O)O',
#  'O=CO)COCO)CO))CO)C5O',
#  '[*]C=O)OCCCO))OC[*])=O',
#  'O=CCO)CO)CO)CO)C6O',
#  'O=PO)O)OCCO)CO)CO)CO)C6O',
#  '[*]C=O)OCCCOP=O)O)OCCO)CO)CO)CO)C6O)))))))))))OC[*])=O',
#  'O=PO)O)OCCOP=O)O)O)))COP=O)O)O)))COP=O)O)O)))COP=O)O)O)))C6OP=O)O)O',
#  'O=PO)O)OCCO)CO)COP=O)O)O)))CO)C6O',
#  'O=PO)O)OCCO)CO)COP=O)O)O)))COP=O)O)O)))C6O',
#  'O=PO)O)OCCO)CO)COP=O)O)O)))COP=O)O)O)))C6O',
#  'O=PO)O)OCCO)COP=O)O)O)))COP=O)O)O)))COP=O)O)O)))C6O',
#  '[*]C=O)OCCCOP=O)O)OCCO)CO)COP=O)O)O)))CO)C6O)))))))))))OC[*])=O',
#  'O=PO)O)OCCO)COP=O)O)O)))COP=O)O)O)))COP=O)O)O)))C6OP=O)O)O',
#  'O=PO)O)OCCO)CO)CO)CO)C6O',
#  'COCCO)CO)CO)CO)C6O',
#  'COCCO)CO)CO)CO)C6O',
#  'O=PO)O)OCCO)CO)CO)CO)C6O',
#  'O=PO)O)OCCO)CO)CO)COP=O)O)O)))C6O',
#  'O=PO)O)OCCO)CO)CO)CO)C6OP=O)O)O',
#  'O=CCCO)CO)CO)C6=O',
#  'O=PO)O)OCCO)COP=O)O)O)))COP=O)O)O)))CO)C6OP=O)O)O',
#  'O=PO)O)OCCO)CO)COP=O)O)O)))COP=O)O)O)))C6OP=O)O)O',
#  '[*]C=O)OCCCOP=O)O)OCCO)CO)CO)COP=O)O)O)))C6O)))))))))))OC[*])=O',
#  'O=PO)O)OCCO)COP=O)O)O)))COP=O)O)O)))COP=O)O)O)))C6OP=O)O)O',
#  'O=PO)O)OCCO)COP=O)O)O)))COP=O)O)O)))COP=O)O)O)))C6OP=O)O)O',
#  '[*]C=O)OCCCOP=O)O)OCCO)CO)COP=O)O)O)))COP=O)O)O)))C6O)))))))))))OC[*])=O',
#  '[*]C=O)OCCCOP=O)O)OCCO)COP=O)O)O)))COP=O)O)O)))COP=O)O)O)))C6O)))))))))))OC[*])=O',
#  'OCCO)CO)CO)CO)C6O',
#  'O=CO)CCO)CO)C=O)CO',
#  'O=CO)CCO)CO)C=O)COP=O)O)O',
#  '[*]C=O)OCCCOP=O)O)OCCO)CO)COP=O)O)O)))COP=O)O)O)))C6O)))))))))))OC[*])=O',
#  'O=PO)O)OCCO)CO)COP=O)O)O)))COP=O)O)O)))C6OP=O)O)O',
#  '[*]C=O)OCCCOP=O)O)OCCO)COP=O)O)O)))CO)COP=O)O)O)))C6O)))))))))))OC[*])=O',
#  '[*]C=O)OCCCOP=O)O)OCCO)CO)CO)COP=O)O)O)))C6O)))))))))))OC[*])=O',
#  'O=CCO)CO)CO)CC=O)O',
#  'NcccnCOCCOP=O)O)OP=O)O)OCCO)CO)CO)CO)C6O)))))))))))))CO)C5O))))))c=O)n6',
#  'O=PO)O)OCCO)CO)CO)COP=O)O)OCCO)CO)CO)CO)C6O))))))))))C6O',
#  'OCCO)CO)CO)CO)C6O',
#  'O=CCO)CO)CO)CO)C6O',
#  'O=CCO)C=O)CO)CO)C6O',
#  'O=CO)CO)CO)CO)C=O)CO',
#  'O',
#  'Ncncncc6ncn5COCCOP=O)O)OP=O)O)OP=O)O)O))))))))CO)C5O',
#  'NC=O)cccc[n+]COCCOP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5O)))))))))))))CO)C5O))))))c6',
#  'NC=O)C=CNCOCCOP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5O)))))))))))))CO)C5O))))))C=CC6',
#  'O=O',
#  'Ncncncc6ncn5COCCOP=O)O)OP=O)O)O))))))CO)C5O',
#  'O=PO)O)O',
#  'O=PO)O)OP=O)O)O',
#  'O=CO)CCC=O)O',
#  'Ccccncc=O)[nH]c=O)nc-6nCCO)CO)CO)COP=O)O)O))))))))c%10cc%14C',
#  '[H+]',
#  'O=CO)C=CC=O)O',
#  '[*]NC=O)CCSCC)C=CC)C=CccCC)SCCNC[*])=O)))C=O)N[*])))))))cC)cn5[Fe]nccC)cCCC=O)O))))c5=CC=NC=C%13)CC)=C5CCC=O)O)))))))))))))=CC%14=N%13))))))))))))))))))NC[*])=O',
#  'O=PO)O)OP=O)O)OP=O)O)O',
#  'O',
#  'Ncncncc6ncn5COCCOP=O)O)OP=O)O)OP=O)O)O))))))))CO)C5O',
#  'NC=O)C=CNCOCCOP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))COP=O)O)O)))C5O)))))))))))))CO)C5O))))))C=CC6',
#  'NC=O)cccc[n+]COCCOP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))COP=O)O)O)))C5O)))))))))))))CO)C5O))))))c6',
#  'O=O',
#  'Ncncncc6ncn5COCCOP=O)O)OP=O)O)O))))))CO)C5O',
#  'O=PO)O)O',
#  '[Mn]',
#  '[H+]',
#  'CCC)=CCcccO)cC)cC)c6O',
#  'O',
#  'O=C=O',
#  'CC=O)C=O)O',
#  'O=CO)CC=O)C=O)O',
#  'CCN)C=O)O',
#  'NCCC=O)O)))C=O)O',
#  'C=COP=O)O)O)))C=O)O',
#  'O=PO)O)OCCOCO)CO))CO)C5O',
#  'O=CCO))COP=O)O)O',
#  'O=PO)O)OCCOCO)CO)C5O',
#  'O=CCO)COP=O)O)O',
#  'O=CO)CCO)C=O)O',
#  'O=CO)CO)COP=O)O)O',
#  'O=CCO))CO)CO)COP=O)O)O',
#  'O=CCO))CO)CO)COP=O)O)O',
#  'O=COP=O)O)O)))CO)COP=O)O)O',
#  'O=CCO)CO)COP=O)O)O',
#  'O=PO)O)OCCOCO)COP=O)O)O))))CO)C5O',
#  'O=CCOP=O)O)O))))CO)CO)CO)CO)COP=O)O)O',
#  'O=CCOP=O)O)O))))CO)CO)COP=O)O)O',
#  'OCCOCO)CO))CO)CO)C6O',
#  'O=CCO))CO)CO)CO)CO)COP=O)O)O',
#  'O=C=O',
#  'CC=O)C=O)O',
#  'CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'O=CO)CCC=O)C=O)O',
#  'CC=O)O',
#  'O=CO)CC=O)C=O)O',
#  'O=CO)CCC=O)O',
#  'O=CC=O)O',
#  'O=CO',
#  'C=COP=O)O)O)))C=O)O',
#  'CCC)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O)))))))))))))))CO)C=O)NCCC=O)NCCSC=O)CC=O)O',
#  'CCC)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O)))))))))))))))CO)C=O)NCCC=O)NCCSC=O)CCC=O)O',
#  'CCC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'Ncnccc=O)[nH]6))NCCNccccC=O)NCCCC=O)O))))C=O)O)))))cc6))))))))CN6',
#  'O=CO)C=CC=O)O',
#  'Ncnccc=O)[nH]6))NCNccccC=O)NCCCC=O)O))))C=O)O)))))cc6))))))CC5CN9',
#  'O=CO)CCO)C=O)O',
#  'O=CO)CCO)CC=O)O)))C=O)O',
#  'O=CCC=O)O',
#  'CC=O)OP=O)O)O',
#  'O=CCCC=O)O',
#  'Ncnccc=O)[nH]6))NCCNC=O))ccccC=O)NCCCC=O)O))))C=O)O)))))cc6))))))))CN6',
#  '[C-]#[O+]',
#  'O=C[O-])O',
#  'O=CO)CCC=O)O))CO)C=O)O',
#  'CC=O)CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'O=CO)C=CCC=O)O)))C=O)O',
#  'CNccncN)[nH]c6=O)))))NCC6CNccccC=O)NCCCC=O)O))))C=O)O)))))cc6',
#  'Ncnccc=O)[nH]6))[N+]=CNccccC=O)NCCCC=O)O))))C=O)O)))))cc6))))))CC5CN9',
#  'CCC)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O)))))))))))))))CO)C=O)NCCC=O)NCCSC=O)CCO)CC=O)O)))C=O)O',
#  'CCC=O)O))C=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CC=CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'C=CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'O=CO)CCCO',
#  'CCO)CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O))))))))))))))))))))))))))))C=O)O',
#  'O=CO)CCO',
#  'CCO)CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCC=O)O))C=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCC)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O)))))))))))))))CO)C=O)NCCC=O)NCCSC=O)CCO)C=O)O',
#  'CCC)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O)))))))))))))))CO)C=O)NCCC=O)NCCSC=O)CCO',
#  'CCC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O)))))))))))))))))))))))))))CO)C=O)O',
#  'CC=CC=O)O)))C=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCC)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O)))))))))))))))CO)C=O)NCCC=O)NCCSC=O)CCCO',
#  'CC=CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O))))))))))))))))))))))))))))C=O)O',
#  'O=C=O',
#  'CC=O)C=O)O',
#  'CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CC=O)O',
#  'O=CO)CC=O)C=O)O',
#  'NCC=O)O',
#  'O=CC=O)O',
#  'O=CO',
#  'NCCO))C=O)O',
#  'C=O',
#  'C=COP=O)O)O)))C=O)O',
#  'NCCccccO)cc6)))))))C=O)O',
#  'O=PO)O)OCCOCO)CO))CO)C5O',
#  'Ncnccc=O)[nH]6))NCCNccccC=O)NCCCC=O)O))))C=O)O)))))cc6))))))))CN6',
#  'O=CCO))COP=O)O)O',
#  'O=CCO)COP=O)O)O',
#  'CO',
#  'Ncnccc=O)[nH]6))NCNccccC=O)NCCCC=O)O))))C=O)O)))))cc6))))))CC5CN9',
#  'O=CO)CCO)C=O)O',
#  'O=CO)C=O)CO',
#  'O=CCO))CO',
#  'O=CO)CO)COP=O)O)O',
#  'O=CCO))CO)CO)COP=O)O)O',
#  'CN',
#  'CC=O)OP=O)O)O',
#  'O=CCO))CO)CO)COP=O)O)O',
#  '[C-]#[O+]',
#  'O=CO)CO)CO',
#  'O=CO)CCCC=O)C=O)O',
#  'O=PO)O)OCCOCO)COP=O)O)O))))CO)C5O',
#  'NCCccccO)cc6',
#  'CNC',
#  'CNC)C',
#  'O=CCS=O)=O)O',
#  'O=CO)CCO))OP=O)O)O',
#  'NCcccCOccccCCNC=O)CCCNC=O)CCCNC=O)CCCC=O)O))CCCC=O)O))))C=O)O))))))))C=O)O)))))))C=O)O)))))))))cc6))))))))co5',
#  'CCOP=O)O)OCCO)CO)CO)Cncnc=O)[nH]c=O)c-6cccccO)cc6%14))))))))))))))))))))))C=O)NCCCC=O)NCCCC=O)O))))C=O)O)))))))C=O)O',
#  'O=CNCcccCOccccCCNC=O)CCCNC=O)CCCNC=O)CCCC=O)O))CCCC=O)O))))C=O)O))))))))C=O)O)))))))C=O)O)))))))))cc6))))))))co5',
#  'NCCOP=O)O)O))))C=O)O',
#  'NCCCC=O)NCCSC=O))))C=O)NCC=O)O))))))))))C=O)O',
#  'CNCCCC=O)O))))C=O)O',
#  'CCOP=O)O)OCCO)CO)CO)CNcccO)ccc6Ccc%10[nH]c=O)[nH]c6=O)))))))))))))))))))))))C=O)NCCCC=O)NCCCC=O)O))))C=O)O)))))))C=O)O',
#  'C[N+]C)C)[O-]',
#  'CCNccccCCO)CO)CO)COCOCCOP=O)O)OCCCC=O)O))))C=O)O)))))))CO)C5O))))))))))))cc6)))))))CNccncN)[nH]c6=O)))))NC6C',
#  'CCNccccCCO)CO)CO)COCOCCOP=O)O)OCCCC=O)O))))C=O)O)))))))CO)C5O))))))))))))cc6)))))))CCC)NcncN)[nH]c=O)c6N%10C=O',
#  'C',
#  'O=CO)C=O)COP=O)O)O',
#  'O=S=O)O)CCS',
#  'CSCCS=O)=O)O',
#  'CCNcncN)[nH]c=O)c6NC=[N+]ccccCCO)CO)CO)COCOCCOP=O)O)OCCCC=O)O))))C=O)O)))))))CO)C5O))))))))))))cc6))))))CC)C%135',
#  'CCC)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O)))))))))))))))CO)C=O)NCCC=O)NCCSC=O)CCO)C=O)O',
#  'CCNcncN)[nH]c=O)c6NCNccccCCO)CO)CO)COCOCCOP=O)O)OCCCC=O)O))))C=O)O)))))))CO)C5O))))))))))))cc6))))))CC)C%135',
#  'CCNccccCCO)CO)CO)COCOCCOP=O)O)OCCCC=O)O))))C=O)O)))))))CO)C5O))))))))))))cc6)))))))CCC)NcncN)[nH]c=O)c6N%10C',
#  'CCOP=O)O)O)))CNC=O)CCCCCCS)))))))))C=O)O',
#  'NccNCCO)CO)CO)CO)))))))[nH]c=O)[nH]c6=O',
#  'CCOP=O)O)O)))CNC=O)CCCCCCSSCCS=O)=O)O))))))))))))))C=O)O',
#  'O=CO)C=O)CS=O)=O)O',
#  'O=CCO)CO)))CO)CO)COP=O)O)O',
#  'O=CO)CCS=O)=O)O)))OP=O)O)O',
#  'O=CO)CO)CS=O)=O)O',
#  'NCCCC=O)NCCSCO))))C=O)NCC=O)O))))))))))C=O)O',
#  'O=CO)CCCCO)CC=O)O)))C=O)O',
#  'O=CO)CCCCC=O)C=O)O',
#  'O=CO)CCCCCC=O)C=O)O',
#  'O=CCCCCCC=O)O',
#  'O=CO)CCCCCCS',
#  'CCO)CNC=O)CCCCCCS)))))))))C=O)O',
#  'O=CO)CCCCC=O)O))CO)C=O)O',
#  'O=CO)CCCCCO)CC=O)O)))C=O)O',
#  'O=CO)CCCCCC=O)O))CO)C=O)O',
#  'CCOP=O)O)OCCO)CO)CO)Cncnc=O)[nH]c=O)c-6cccccO)cc6%14))))))))))))))))))))))C=O)NCCCC=O)NCCCC=O)NCCCC=O)O))))C=O)O)))))))C=O)O)))))))C=O)O',
#  'CCOP=O)O)OCCO)CO)CO)Cncnc=O)[nH]c=O)c-6cccccO)cc6%14))))))))))))))))))))))C=O)NCCCC=O)O))))C=O)O',
#  'CCOP=O)O)OCCO)CO)CO)Cncnc=O)[nH]c=O)c-6cccccO)cc6%14))))))))))))))))))))))C=O)O',
#  'O=cncnCCO)CO)CO)CO))))))cccO)ccc6cc-%10c=O)[nH]%14',
#  'CCOP=O)O)OP=O)O)OCCOCncncc=O)[nH]cN)nc69)))))))))CO)C5O))))))))))))C=O)O',
#  'CCOP=O)O)O)))C=O)O',
#  'O=CO)C=CCCCC=O)O)))))C=O)O',
#  'O=CO)C=CCCCCC=O)O))))))C=O)O',
#  'NCCCC=O)NCCccccO)cc6))))))))))))C=O)O',
#  'O=CcccCOP=O)O)O))))co5',
#  'NCcccCOP=O)O)O))))co5',
#  'NCcccCOP=O)O)OP=O)O)O))))))co5',
#  'NCcccCOccccCCNC=O)CCCN)C=O)O)))))))))cc6))))))))co5',
#  'NCCccccO)cc6)))))))C=O)NC=O)NC6=NCCO)CO)CO)CO',
#  'O=C=O',
#  'N',
#  'NCCCC=O)O))))C=O)O',
#  'O=CO',
#  'NC=O)CCCN)C=O)O',
#  'O=NO',
#  'NC=O)OP=O)O)O',
#  'NO',
#  'O=[N+][O-])O',
#  'O=C[O-])O',
#  'NC=O',
#  '[N]=O',
#  'N#N',
#  '[*]C#N',
#  '[N-]=[N+]=O',
#  'N#CO',
#  'NC=O)O',
#  'NN',
#  '[*][N+]=O)[O-]',
#  'CC=O)O',
#  'O=CO)CCC=O)O',
#  'Ncncncc6ncn5COCCOP=O)O)OS=O)=O)O))))))COP=O)O)O)))C5O',
#  'Ncncncc6ncn5COCCOP=O)O)O))))COP=O)O)O)))C5O',
#  'O=S=O)O)O',
#  'NCCO))C=O)O',
#  'CC=O',
#  '[S]',
#  'O=SO)O',
#  'NCCS))C=O)O',
#  'NCCCS)))C=O)O',
#  'Ncncncc6ncn5COCCOP=O)O)OS=O)=O)O))))))CO)C5O',
#  'NCCS=O)=O)O',
#  'NCCCO)))C=O)O',
#  'S',
#  'O=S=O)O)[S-]',
#  'CS',
#  'CSC',
#  'CC=O)OCCN)C=O)O',
#  'NCCCOC=O)CCC=O)O))))))))C=O)O',
#  'O=S=O)[O-])SS=O)=O)[O-]',
#  'O=S=O)O)SSS=O)=O)O',
#  'CSCCS=O)=O)O',
#  'C[S+]C)CCC=O)[O-]',
#  'CSCCC=O)O',
#  'CSC)=O)=O',
#  'CSC)=O',
#  'CS=O)=O)O',
#  '[*]CS=O)=O)O',
#  'NCCCC=O)NCCSS)))C=O)NCC=O)O))))))))))C=O)O',
#  'CSCCC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CSC=CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCC)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O)))))))))))))))CO)C=O)NCCC=O)NCCSC=O)CC=O)O',
#  'CCCCCCCCCCCCCCCC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  '[*]S',
#  'CCCCCCCCCCCCCCCC=O)O',
#  'CCCCCCCCC=CCCCCCCCC=O)O',
#  '[*]SC=O)CCCCCCCC=CCCCCCCCC',
#  '[*]SC=O)CC=O)O',
#  'CCCCCCCCCCCCCCCCCC=O)O',
#  'CCCCCCCCCC=O)O',
#  'CCCCCCCCCCCC=O)O',
#  '[*]SCC)=O',
#  '[*]SC=O)CCCCCCCCCCCCCCCCC',
#  '[*]SC=O)CC=CCCCCCC',
#  '[*]SC=O)C=CC',
#  '[*]SC=O)CCC)O',
#  '[*]SC=O)CCO)CCCCCCC',
#  '[*]SC=O)CCO)CCCCC',
#  '[*]SC=O)CCO)CCCCCCCCCCCCC',
#  '[*]SC=O)CCO)CCCCCCCCCCC',
#  '[*]SC=O)CCCCCCCCCCC',
#  '[*]SC=O)CCC)=O',
#  '[*]SC=O)CCC',
#  '[*]SC=O)CC=O)CCC',
#  '[*]SC=O)CCO)CCC',
#  '[*]SC=O)C=CCCC',
#  '[*]SC=O)CCCCC',
#  '[*]SC=O)CC=O)CCCCC',
#  '[*]SC=O)C=CCCCCC',
#  '[*]SC=O)CCCCCCC',
#  '[*]SC=O)CC=O)CCCCCCC',
#  '[*]SC=O)C=CCCCCCCC',
#  '[*]SC=O)CCCCCCCCC',
#  '[*]SC=O)CC=O)CCCCCCCCC',
#  '[*]SC=O)CCO)CCCCCCCCC',
#  '[*]SC=O)C=CCCCCCCCCC',
#  '[*]SC=O)CC=O)CCCCCCCCCCC',
#  '[*]SC=O)C=CCCCCCCCCCCC',
#  '[*]SC=O)CCCCCCCCCCCCC',
#  '[*]SC=O)CC=O)CCCCCCCCCCCCC',
#  '[*]SC=O)C=CCCCCCCCCCCCCC',
#  '[*]SC=O)CCCCCCCCCCCCCCC',
#  'CCCCCCCC=O)O',
#  'CCCCCCCCCCCCCC=O)O',
#  'CCCCCCC=CCCCCCCCC=O)O',
#  '[*]SC=O)CC=O)CCCCCCCCCCCCCCC',
#  '[*]SC=O)CCO)CCCCCCCCCCCCCCC',
#  '[*]SC=O)C=CCCCCCCCCCCCCCCC',
#  '[*]SC=O)CCCCCCCC=CCCCCCC',
#  'CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  '[*]C=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCC)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O)))))))))))))))CO)C=O)NCCC=O)NCCSC=O)CC=O)O',
#  'CCCC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCCCCCCCCCCCCCCC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  '[*]C=O)O',
#  'CCCCCCCCCCCCCCCC=O)O',
#  '[*]C=O)CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  '[*]C=CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  '[*]CCC=O)O',
#  '[*]CO)CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  '[*]C=CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCCCCCCCCCCC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCCCCCCC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCCCCCCCCCCCCC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCCCCCCCCC=CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCCCCCCCCCCCCCO)CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCCCCCCCCCCCCC=O)CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCCCCCCCCCCCO)CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCCCCCCCCCCC=O)CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCCCCCCCCCO)CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCCCCCCCCC=O)CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCCCCCCCO)CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCCCCCCC=O)CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCCCCCO)CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCCCCC=O)CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCCCO)CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCCC=O)CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCCCCC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCCC=CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCCCCCCCCCCCCC=CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCCCCCCCCCCC=CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCCCCCCCCC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCCCCCCC=CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCCCCC=CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  '[*]CCC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  '[*]C=O)CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  '[*]CO)CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  '[*]C=CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCC)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O)))))))))))))))CO)C=O)NCCC=O)NCCS',
#  'CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  '[*]C=O',
#  'CCCC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCCCCCCCCCCCCCCC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  '[*]C=O)O',
#  '[*]CO',
#  '[*]S',
#  'CCCCCCCCCCCCCCCC=O)O',
#  'CC=O)CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'O=CO)CCCC=O)O',
#  'CCCCCCCCCCCCCCCC=O',
#  'CCC)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O)))))))))))))))CO)C=O)NCCC=O)NCCSC=O)CCCC=O)O',
#  '[*]CCC=O)O',
#  'CCCCCCCCCCCCCCCCO',
#  'CC=CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCO)CC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  '[*][H]',
#  'CCCCCCCCCCCC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCCCCCCC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  'CCCCCCCCCCCCCC=O)SCCNC=O)CCNC=O)CO)CC)C)COP=O)O)OP=O)O)OCCOCncnccN)ncnc69)))))))))CO)C5OP=O)O)O',
#  ...]
